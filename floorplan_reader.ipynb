# %%
from PIL import Image
image = Image.open("./images/raw/fp3.jpg")
image = image.convert('L')
image = image.point(lambda x: 0 if x < 200 else 255, '1')
image.save("./images/processed/fp3.jpg")
image
# Out:
# <PIL.Image.Image image mode=1 size=1086x1222 at 0x26BB3767CC8>

# %%
from tesserocr import PyTessBaseAPI

with PyTessBaseAPI() as api:
    api.SetImageFile("./images/raw/fp3.jpg")
    result = api.GetUTF8Text()
    confidence = api.AllWordConfidences()

# %%
import pandas as pd

result
result_df = pd.DataFrame([result])
result_df.columns = ['fp_text']
result
# Out:
# " \n\n \n\n \n\n \n\n \n\n \n\nSITE PLAN\n\n \n\nFLOOR PLAN\n\nDimensions are approximate measurements; we cannot guarantee its accuracy. No liability will be accepted for any misinformation\n\n \n\nPergola\n80x59\n. '\n,\nRumpus\n39x39\nBed\n29x59\n\n \n\nBed\n29x24\n\n \n\n[eT\n\nAlresco —\n9x4, loots Verandah\nies 39x49 ee\n. ‘\n\nLounge Bacher\n\n59x49 sa\n\n \n"

# %%
# text processor
import nltk
import bs4
import string
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
nltk.download()

# %%
def remove_punc(text):
    no_punc = "".join([c for c in text if c not in string.punctuation])
    return no_punc

def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

lemmatizer = WordLemmatizer()

def word_lemmatizer(x):
    lem_text = [lemmatizer.lemmatize(i) for i in text]
    return le,_text

# %%
#punctuation
result_df['fp_text'] = result_df['fp_text'].apply(lambda x : remove_punc(x))

#tokenise
tokenizer = RegexpTokenizer(r'\w+')
result_df['fp_text'] = result_df['fp_text'].apply(lambda x: tokenizer.tokenize(x.lower()))

#stop words
result_df['fp_text'] = result_df['fp_text'].apply(lambda x : remove_stopwords(x))

#stop words
result_df['fp_text'].apply(lambda x : word_lemmatizer(x))

print(result_df)

# %%
fp_text
