# %%
from PIL import Image
image = Image.open("./images/raw/fp1.jpg")
image = image.convert('L')
image = image.point(lambda x: 0 if x < 200 else 255, '1')
image.save("./images/processed/fp1.jpg")
image
# Out:
# <PIL.Image.Image image mode=1 size=1215x1448 at 0x10CB815C0>

# %%
import pytesseract

# If you don't have tesseract executable in your PATH, include the following:
pytesseract.pytesseract.tesseract_cmd = r'<full_path_to_your_tesseract_executable>'
# Example tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'

# Simple image to string
print(pytesseract.image_to_string(Image.open('test.png')))

# French text image to string
print(pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra'))

# In order to bypass the image conversions of pytesseract, just use relative or absolute image path
# NOTE: In this case you should provide tesseract supported images or tesseract will return error
print(pytesseract.image_to_string('test.png'))

# Batch processing with a single file containing the list of multiple image file paths
print(pytesseract.image_to_string('images.txt'))

# Get bounding box estimates
print(pytesseract.image_to_boxes(Image.open('test.png')))

# Get verbose data including boxes, confidences, line and page numbers
print(pytesseract.image_to_data(Image.open('test.png')))

# Get information about orientation and script detection
print(pytesseract.image_to_osd(Image.open('test.png')))

# Get a searchable PDF
pdf = pytesseract.image_to_pdf_or_hocr('test.png', extension='pdf')

# Get HOCR output
hocr = pytesseract.image_to_pdf_or_hocr('test.png', extension='hocr')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-be21e0b7d8ec> in <module>
# ----> 1 from tesserocr import PyTessBaseAPI
#       2
#       3 with PyTessBaseAPI() as api:
#       4     api.SetImageFile("./images/raw/fp3.jpg")
#       5     result = api.GetUTF8Text()
#
# ModuleNotFoundError: No module named 'tesserocr'

# %%
import pandas as pd

result
result_df = pd.DataFrame([result])
result_df.columns = ['fp_text']
result
# Out:
# " \n\n \n\n \n\n \n\n \n\n \n\nSITE PLAN\n\n \n\nFLOOR PLAN\n\nDimensions are approximate measurements; we cannot guarantee its accuracy. No liability will be accepted for any misinformation\n\n \n\nPergola\n80x59\n. '\n,\nRumpus\n39x39\nBed\n29x59\n\n \n\nBed\n29x24\n\n \n\n[eT\n\nAlresco —\n9x4, loots Verandah\nies 39x49 ee\n. ‘\n\nLounge Bacher\n\n59x49 sa\n\n \n"

# %%
# text processor
import nltk
import bs4
import string
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
nltk.download()

# %%
def remove_punc(text):
    no_punc = "".join([c for c in text if c not in string.punctuation])
    return no_punc

def remove_stopwords(text):
    words = [w for w in text if w not in stopwords.words('english')]
    return words

lemmatizer = WordLemmatizer()

def word_lemmatizer(x):
    lem_text = [lemmatizer.lemmatize(i) for i in text]
    return le,_text

# %%
#punctuation
result_df['fp_text'] = result_df['fp_text'].apply(lambda x : remove_punc(x))

#tokenise
tokenizer = RegexpTokenizer(r'\w+')
result_df['fp_text'] = result_df['fp_text'].apply(lambda x: tokenizer.tokenize(x.lower()))

#stop words
result_df['fp_text'] = result_df['fp_text'].apply(lambda x : remove_stopwords(x))

#stop words
result_df['fp_text'].apply(lambda x : word_lemmatizer(x))

print(result_df)

# %%
fp_text
